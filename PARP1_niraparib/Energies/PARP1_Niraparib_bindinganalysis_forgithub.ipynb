# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
DDG_data = pd.read_csv("./Energies_PARP1.txt")

# %%
## Convert mutation names to a more readable format
DDG_data["start"] = DDG_data["Mutation"].str[:1]
DDG_data["end"] = DDG_data["Mutation"].str[2:]
DDG_data["Mutationname"] = DDG_data["start"] + DDG_data["end"]

# %%
DDG_data
# Out:
#      Mutation  WT_energy  MUT_energy       DDG start   end Mutationname
# 0      LA984F   0.446814    0.427181 -0.019633     L  984F        L984F
# 1      LA984W   0.498652    0.409781 -0.088871     L  984W        L984W
# 2      LA984Q   0.438464    0.370373 -0.068091     L  984Q        L984Q
# 3      LA984E   0.438464    0.583800  0.145336     L  984E        L984E
# 4      LA984P   0.438464    0.395907 -0.042557     L  984P        L984P
# ...       ...        ...         ...       ...   ...   ...          ...
# 1382   PA885Q   0.508052    0.508616  0.000564     P  885Q        P885Q
# 1383   PA885N   0.508052    0.508616  0.000564     P  885N        P885N
# 1384   PA885Y   0.486953    0.585792  0.098839     P  885Y        P885Y
# 1385   PA885E   0.508052    0.071982 -0.436070     P  885E        P885E
# 1386   PA885I   0.508052    0.508616  0.000564     P  885I        P885I
#
# [1387 rows x 7 columns]

# %%
g = sns.barplot(y = DDG_data.sort_values(by = "DDG").head(10)["DDG"]
                , x = DDG_data.sort_values(by = "DDG").head(10)["Mutationname"], edgecolor = "k",
               palette = sns.color_palette("Set3"))
g.tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)

g.set_ylim(-2, 0)
g.set_xlabel("")
g.set_xticklabels(g.get_xticklabels(), size = 10)
g.set_yticklabels(g.get_yticklabels(), size = 12)
g.set_ylabel("Binding DDG (kcal/mol)", size = 14)
sns.despine(top = False, bottom = True)

plt.savefig("Niraparib_binding_lowest10.pdf", bbox_inches="tight")

plt.show()
# Out:
# <ipython-input-5-735c14f4b2cc>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(g.get_yticklabels(), size = 12)

# %%
g = sns.barplot(y = DDG_data.sort_values(by = "DDG").tail(10)["DDG"]
                , x = DDG_data.sort_values(by = "DDG").tail(10)["Mutationname"], edgecolor = "k",
               palette = sns.color_palette("Set3"))

g.set_xlabel("")
g.set_xticklabels(g.get_xticklabels(), size = 10)
g.set_yticklabels(g.get_yticklabels(), size = 12)
g.set_ylabel("Binding DDG (kcal/mol)", size = 14)
sns.despine()

plt.savefig("Niraparib_binding_highest10.pdf", bbox_inches="tight")

plt.show()
# Out:
# <ipython-input-6-b06af004cdcc>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(g.get_yticklabels(), size = 12)
